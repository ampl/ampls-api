# %% [markdown]
# # AMPLPY: Pattern Generation
#
# Documentation: http://amplpy.readthedocs.io
#
# GitHub Repository: https://github.com/ampl/amplpy
#
# PyPI Repository: https://pypi.python.org/pypi/amplpy

# %% [markdown]
# ### Imports

# %%
from __future__ import print_function
from amplpy import AMPL
import os, sys
from math import floor, ceil

# %%
# Import scippy
import amplpy_scip as gpy
gpy.patch(AMPL)

# if it fails to find amplpy_scip inside the virtualenv, create a kernel inside the virtualenv and use it:
# $ ipython kernel install --user --name=.venv

# %% [markdown]
# ### Register jupyter magics for AMPL

# %%
from amplpy import register_magics
register_magics('_ampl_cells')  # Store %%ampl cells in the list _ampl_cells

# %% [markdown]
# ### Basic pattern-cutting model

# %%
# %%ampl
# param nPatterns integer > 0;
#
# set PATTERNS = 1..nPatterns;  # patterns
# set WIDTHS;                   # finished widths
#
# param order {WIDTHS} >= 0;    # rolls of width j ordered
# param overrun;                # permitted overrun on any width
#
# param rawWidth;               # width of raw rolls to be cut
# param rolls {WIDTHS,PATTERNS} >= 0, default 0;
#                               # rolls of width i in pattern j
#
# var Cut {PATTERNS} integer >= 0;  # raw rolls to cut in each pattern
#
# minimize TotalRawRolls: sum {p in PATTERNS} Cut[p];
#
# subject to OrderLimits {w in WIDTHS}:
#   order[w] <= sum {p in PATTERNS} rolls[w,p] * Cut[p] <= order[w] + overrun;

# %% [markdown]
# ### Plotting routine

# %%
def cuttingPlot(roll_width, widths, summary, solution):
    import numpy as np
    import matplotlib.pyplot as plt
    nchuncks = max(int(ceil(len(solution)/25.0)), 1)
    chunck_size = int(ceil(len(solution)/float(nchuncks)))
    start = 0
    for i in range(nchuncks):            
        plt.subplot(1, nchuncks, i+1)        
        sol = solution[start:start+chunck_size]
        start += chunck_size
        ind = np.arange(len(sol))
        acc = [0]*len(sol)
        colorlist = ['red','lightblue','orange','lightgreen',
                     'brown','fuchsia','silver','goldenrod']
        for p, (patt, rep) in enumerate(sol):
            for i in range(len(widths)):
                for j in range(patt[i]):
                    vec = [0]*len(sol)
                    vec[p] = widths[i]
                    plt.barh(ind, vec, 0.6, acc, 
                             color=colorlist[i%len(colorlist)], edgecolor='black')
                    acc[p] += widths[i]
        plt.xlim(0, roll_width)
        #plt.xticks(np.arange(0, roll_width, 10))
        plt.yticks(ind, tuple("x {:}".format(rep) for patt, rep in sol))
    plt.suptitle('{}: {} rolls, {} patterns, {:.2f}% waste'.format(
        summary['Data'],
        summary['Obj'],
        len(solution),
        round(100*summary['Waste']/(roll_width*summary['Obj']),2),
    ))   
    plt.show()

# %% [markdown]
# ### Set parameters

# %%
cutdata = 'SeymaDogan.py'
#cutdata = 'ChvatalD.py'
stopdata = 'stopdata'

# %% [markdown]
# ### Read orders, roll_width, overrun; extract widths

# %%
exec(open(os.path.join('CuttingCases', cutdata)).read(), globals())
widths = list(sorted(orders.keys(), reverse=True))

# %% [markdown]
# ### Set up cutting (master problem) model

# %%
Master = AMPL()
Master.option['ampl_include'] = 'models'
Master.eval(_ampl_cells[0])

# %% [markdown]
# ### Send data to AMPL

# %%
# Send scalar values
Master.param['nPatterns'] = len(widths)
Master.param['overrun'] = overrun
Master.param['rawWidth'] = roll_width
# Send order vector
Master.set['WIDTHS'] = widths
Master.param['order'] = orders
# Generate and send initial pattern matrix
Master.param['rolls'] = {
    (widths[i], 1+i): int(floor(roll_width/widths[i]))
    for i in range(len(widths))
}

# %% [markdown]
# ### Set up for generation loop

# %%
# Define a param for sending AMPL new patterns
Master.eval('param newPat {WIDTHS} integer >= 0;')

# Set solve options
Master.option['solver'] = 'scip'
Master.option['relax_integrality'] =  1

# %% [markdown]
# ### Define the knapsack subproblem

# %%
# Define knapsack subproblem
Sub = AMPL()
Sub.option['solver'] = 'scip'

Sub.eval('''
    set SIZES;
    param cap >= 0;
    param val {SIZES};
    var Qty {SIZES} integer >= 0;
    maximize TotVal: sum {s in SIZES} val[s] * Qty[s];
    subject to Cap: sum {s in SIZES} s * Qty[s] <= cap;
''')

# Send subproblem data
Sub.set['SIZES'] = widths
Sub.param['cap'] = roll_width

# %% [markdown]
# ### Loop

# %%
while True:    
    Master.solve()

    Sub.param['val'].setValues(Master.con['OrderLimits'].getValues())
    Sub.solve()    
    if Sub.obj['TotVal'].value() <= 1.00001:        
        break        

    Master.param['newPat'].setValues(Sub.var['Qty'].getValues())
    Master.eval('let nPatterns := nPatterns + 1;')
    Master.eval('let {w in WIDTHS} rolls[w, nPatterns] := newPat[w];')
# Out:
# scip 8.1.0: optimal solution; objective 1169.000124
# scip 8.1.0: optimal solution; objective 1.283333333
# 5 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1167.111236
# scip 8.1.0: optimal solution; objective 1.283333333
# 4 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1165.566791
# 1 simplex iterations
# scip 8.1.0: optimal solution; objective 1.283333333
# 6 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1163.677902
# scip 8.1.0: optimal solution; objective 1.276923077
# 7 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1157.539441
# 4 simplex iterations
# scip 8.1.0: optimal solution; objective 1.276923077
# 20 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1156.893287
# 7 simplex iterations
# scip 8.1.0: optimal solution; objective 1.266666667
# 7 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1154.915509
# 8 simplex iterations
# scip 8.1.0: optimal solution; objective 1.265384615
# 109 simplex iterations
# 50 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1151.843287
# 8 simplex iterations
# scip 8.1.0: optimal solution; objective 1.257575758
# 21 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1150.507117
# 12 simplex iterations
# scip 8.1.0: optimal solution; objective 1.253968254
# 43 simplex iterations
# 9 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1147.538863
# 12 simplex iterations
# scip 8.1.0: optimal solution; objective 1.253968254
# 52 simplex iterations
# 31 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1143.300768
# 12 simplex iterations
# scip 8.1.0: optimal solution; objective 1.253968254
# 48 simplex iterations
# 29 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1142.041509
# 19 simplex iterations
# scip 8.1.0: optimal solution; objective 1.25
# 13 simplex iterations
# 9 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1139.374842
# 19 simplex iterations
# scip 8.1.0: optimal solution; objective 1.201923077
# 89 simplex iterations
# 18 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1137.730612
# 22 simplex iterations
# scip 8.1.0: optimal solution; objective 1.201923077
# 70 simplex iterations
# 17 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1134.961381
# 19 simplex iterations
# scip 8.1.0: optimal solution; objective 1.201923077
# 69 simplex iterations
# 18 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1134.009458
# 18 simplex iterations
# scip 8.1.0: optimal solution; objective 1.243614719
# 71 simplex iterations
# 23 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1133.74629
# 16 simplex iterations
# scip 8.1.0: optimal solution; objective 1.196428571
# 52 simplex iterations
# 14 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1121.960576
# 26 simplex iterations
# scip 8.1.0: optimal solution; objective 1.196428571
# 91 simplex iterations
# 30 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1120.385942
# 24 simplex iterations
# scip 8.1.0: optimal solution; objective 1.196428571
# 80 simplex iterations
# 27 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1114.758195
# 26 simplex iterations
# scip 8.1.0: optimal solution; objective 1.196428571
# 43 simplex iterations
# 10 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1113.540729
# 22 simplex iterations
# scip 8.1.0: optimal solution; objective 1.195488722
# 85 simplex iterations
# 18 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1089.067045
# 22 simplex iterations
# scip 8.1.0: optimal solution; objective 1.194444444
# 274 simplex iterations
# 101 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1087.992971
# 22 simplex iterations
# scip 8.1.0: optimal solution; objective 1.238111888
# 19 simplex iterations
# 6 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1084.49186
# 30 simplex iterations
# scip 8.1.0: optimal solution; objective 1.194444444
# 149 simplex iterations
# 73 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1082.27364
# 33 simplex iterations
# scip 8.1.0: optimal solution; objective 1.194300144
# 105 simplex iterations
# 56 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1079.422558
# 27 simplex iterations
# scip 8.1.0: optimal solution; objective 1.194444444
# 41 simplex iterations
# 12 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1077.228114
# 33 simplex iterations
# scip 8.1.0: optimal solution; objective 1.190909091
# 33 simplex iterations
# 7 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1076.245574
# 29 simplex iterations
# scip 8.1.0: optimal solution; objective 1.202380952
# 13 simplex iterations
# 9 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1075.701923
# 30 simplex iterations
# scip 8.1.0: optimal solution; objective 1.203968254
# 44 simplex iterations
# 24 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1075.087778
# 33 simplex iterations
# scip 8.1.0: optimal solution; objective 1.195970696
# 48 simplex iterations
# 27 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1067.719101
# 42 simplex iterations
# scip 8.1.0: optimal solution; objective 1.194444444
# 6 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1066.573654
# 40 simplex iterations
# scip 8.1.0: optimal solution; objective 1.189044289
# 19 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1065.136233
# 44 simplex iterations
# scip 8.1.0: optimal solution; objective 1.237179487
# 21 simplex iterations
# 8 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1063.382814
# 40 simplex iterations
# scip 8.1.0: optimal solution; objective 1.25
# 7 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1062.627137
# 38 simplex iterations
# scip 8.1.0: optimal solution; objective 1.196784697
# 12 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1061.565374
# 35 simplex iterations
# scip 8.1.0: optimal solution; objective 1.20021811
# 24 simplex iterations
# 10 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1060.218864
# 36 simplex iterations
# scip 8.1.0: optimal solution; objective 1.194444444
# 60 simplex iterations
# 21 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1058.915412
# 31 simplex iterations
# scip 8.1.0: optimal solution; objective 1.157322616
# 241 simplex iterations
# 130 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1056.846429
# 37 simplex iterations
# scip 8.1.0: optimal solution; objective 1.107142857
# 98 simplex iterations
# 83 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1056.507784
# 37 simplex iterations
# scip 8.1.0: optimal solution; objective 1.123168498
# 48 simplex iterations
# 25 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1052.198545
# 42 simplex iterations
# scip 8.1.0: optimal solution; objective 1.122377622
# 31 simplex iterations
# 12 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1051.982342
# 39 simplex iterations
# scip 8.1.0: optimal solution; objective 1.10044955
# 6 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1051.043783
# 43 simplex iterations
# scip 8.1.0: optimal solution; objective 1.095970696
# 139 simplex iterations
# 76 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1050.453415
# 50 simplex iterations
# scip 8.1.0: optimal solution; objective 1.083333333
# 5 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1050.134759
# 50 simplex iterations
# scip 8.1.0: optimal solution; objective 1.092592593
# 5 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1047.204287
# 66 simplex iterations
# scip 8.1.0: optimal solution; objective 1.087784803
# 5 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1044.332747
# 63 simplex iterations
# scip 8.1.0: optimal solution; objective 1.119067183
# 5 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1044.269334
# 61 simplex iterations
# scip 8.1.0: optimal solution; objective 1.083333333
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1043.428431
# 49 simplex iterations
# scip 8.1.0: optimal solution; objective 1.083028083
# 162 simplex iterations
# 93 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1042.59559
# 45 simplex iterations
# scip 8.1.0: optimal solution; objective 1.08788289
# 10 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1042.555265
# 44 simplex iterations
# scip 8.1.0: optimal solution; objective 1.087107235
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1040.442267
# 46 simplex iterations
# scip 8.1.0: optimal solution; objective 1.099376924
# 10 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1039.709648
# 49 simplex iterations
# scip 8.1.0: optimal solution; objective 1.08452381
# 57 simplex iterations
# 27 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1039.545122
# 47 simplex iterations
# scip 8.1.0: optimal solution; objective 1.093257518
# 5 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1039.385289
# 55 simplex iterations
# scip 8.1.0: optimal solution; objective 1.095980088
# 50 simplex iterations
# 22 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1039.322533
# 55 simplex iterations
# scip 8.1.0: optimal solution; objective 1.079365079
# 14 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1038.925708
# 55 simplex iterations
# scip 8.1.0: optimal solution; objective 1.076957963
# 30 simplex iterations
# 8 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1038.523933
# 56 simplex iterations
# scip 8.1.0: optimal solution; objective 1.083333333
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1038.321552
# 53 simplex iterations
# scip 8.1.0: optimal solution; objective 1.071428571
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1038.226314
# 53 simplex iterations
# scip 8.1.0: optimal solution; objective 1.055469028
# 6 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1038.17795
# 53 simplex iterations
# scip 8.1.0: optimal solution; objective 1.053571429
# 46 simplex iterations
# 16 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1037.374378
# 53 simplex iterations
# scip 8.1.0: optimal solution; objective 1.050671551
# 19 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1036.653145
# 57 simplex iterations
# scip 8.1.0: optimal solution; objective 1.049279942
# 86 simplex iterations
# 45 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1036.160345
# 57 simplex iterations
# scip 8.1.0: optimal solution; objective 1.047619048
# 64 simplex iterations
# 35 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1034.493678
# 57 simplex iterations
# scip 8.1.0: optimal solution; objective 1.04729121
# 30 simplex iterations
# 12 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1031.782542
# 69 simplex iterations
# scip 8.1.0: optimal solution; objective 1.03994789
# 10 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1031.778548
# 74 simplex iterations
# scip 8.1.0: optimal solution; objective 1.030973869
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1031.690774
# 61 simplex iterations
# scip 8.1.0: optimal solution; objective 1.027633056
# 182 simplex iterations
# 96 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1031.628878
# 61 simplex iterations
# scip 8.1.0: optimal solution; objective 1.020628256
# 6 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1031.538053
# 58 simplex iterations
# scip 8.1.0: optimal solution; objective 1.020898355
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1031.367233
# 69 simplex iterations
# scip 8.1.0: optimal solution; objective 1.018751127
# 18 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1031.293099
# 68 simplex iterations
# scip 8.1.0: optimal solution; objective 1.046703297
# 18 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1031.251585
# 74 simplex iterations
# scip 8.1.0: optimal solution; objective 1.017020228
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1030.291564
# 66 simplex iterations
# scip 8.1.0: optimal solution; objective 1.020242915
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1030.280305
# 66 simplex iterations
# scip 8.1.0: optimal solution; objective 1.016362692
# 5 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1029.970661
# 73 simplex iterations
# scip 8.1.0: optimal solution; objective 1.018583532
# 432 simplex iterations
# 281 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1029.646221
# 71 simplex iterations
# scip 8.1.0: optimal solution; objective 1.013424243
# 4 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1029.623847
# 73 simplex iterations
# scip 8.1.0: optimal solution; objective 1.013178986
# 6 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1029.505727
# 83 simplex iterations
# scip 8.1.0: optimal solution; objective 1.016657969
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1029.098481
# 73 simplex iterations
# scip 8.1.0: optimal solution; objective 1.012700997
# 4 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1028.87824
# 69 simplex iterations
# scip 8.1.0: optimal solution; objective 1.011676454
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1028.629314
# 75 simplex iterations
# scip 8.1.0: optimal solution; objective 1.010413647
# 13 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1028.439252
# 78 simplex iterations
# scip 8.1.0: optimal solution; objective 1.039748015
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1028.43146
# 79 simplex iterations
# scip 8.1.0: optimal solution; objective 1.007787107
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1028.267092
# 80 simplex iterations
# scip 8.1.0: optimal solution; objective 1.041405094
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1028.252397
# 81 simplex iterations
# scip 8.1.0: optimal solution; objective 1.00824661
# 6 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1028.210428
# 89 simplex iterations
# scip 8.1.0: optimal solution; objective 1.006727819
# 13 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1028.181313
# 87 simplex iterations
# scip 8.1.0: optimal solution; objective 1.007782016
# 9 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.931874
# 83 simplex iterations
# scip 8.1.0: optimal solution; objective 1.010924553
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.931874
# 83 simplex iterations
# scip 8.1.0: optimal solution; objective 1.009271474
# 7 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.847722
# 85 simplex iterations
# scip 8.1.0: optimal solution; objective 1.008937427
# 4 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.846301
# 96 simplex iterations
# scip 8.1.0: optimal solution; objective 1.008668724
# 13 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.819546
# 93 simplex iterations
# scip 8.1.0: optimal solution; objective 1.007724784
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.808018
# 99 simplex iterations
# scip 8.1.0: optimal solution; objective 1.005438115
# 7 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.756296
# 81 simplex iterations
# scip 8.1.0: optimal solution; objective 1.008317973
# 562 simplex iterations
# 365 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.625702
# 97 simplex iterations
# scip 8.1.0: optimal solution; objective 1.008238909
# 12 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.598796
# 84 simplex iterations
# scip 8.1.0: optimal solution; objective 1.008630464
# 8 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.598604
# 84 simplex iterations
# scip 8.1.0: optimal solution; objective 1.004195053
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.556566
# 90 simplex iterations
# scip 8.1.0: optimal solution; objective 1.003448228
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.461935
# 81 simplex iterations
# scip 8.1.0: optimal solution; objective 1.003399276
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.311677
# 86 simplex iterations
# scip 8.1.0: optimal solution; objective 1.006823314
# 8 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.305385
# 86 simplex iterations
# scip 8.1.0: optimal solution; objective 1.00556332
# 10 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.304515
# 87 simplex iterations
# scip 8.1.0: optimal solution; objective 1.003466141
# 7 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.253722
# 83 simplex iterations
# scip 8.1.0: optimal solution; objective 1.004860433
# 4 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.251187
# 85 simplex iterations
# scip 8.1.0: optimal solution; objective 1.005212325
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.250797
# 86 simplex iterations
# scip 8.1.0: optimal solution; objective 1.004630478
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.248993
# 86 simplex iterations
# scip 8.1.0: optimal solution; objective 1.004021481
# 10 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.241868
# 87 simplex iterations
# scip 8.1.0: optimal solution; objective 1.003217293
# 6 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.23892
# 87 simplex iterations
# scip 8.1.0: optimal solution; objective 1.003700533
# 6 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.238621
# 87 simplex iterations
# scip 8.1.0: optimal solution; objective 1.002787281
# 995 simplex iterations
# 719 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.22886
# 78 simplex iterations
# scip 8.1.0: optimal solution; objective 1.006618395
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.227952
# 78 simplex iterations
# scip 8.1.0: optimal solution; objective 1.004691512
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.22468
# 79 simplex iterations
# scip 8.1.0: optimal solution; objective 1.002567539
# 1444 simplex iterations
# 1021 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.210118
# 72 simplex iterations
# scip 8.1.0: optimal solution; objective 1.004702418
# 575 simplex iterations
# 420 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.198784
# 74 simplex iterations
# scip 8.1.0: optimal solution; objective 1.003401209
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.195451
# 80 simplex iterations
# scip 8.1.0: optimal solution; objective 1.002367426
# 2086 simplex iterations
# 1037 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.185983
# 80 simplex iterations
# scip 8.1.0: optimal solution; objective 1.002321712
# 3212 simplex iterations
# 1645 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.163308
# 79 simplex iterations
# scip 8.1.0: optimal solution; objective 1.002497472
# 12 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.146503
# 87 simplex iterations
# scip 8.1.0: optimal solution; objective 1.002727731
# 4 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.141086
# 87 simplex iterations
# scip 8.1.0: optimal solution; objective 1.002592223
# 4 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.073676
# 92 simplex iterations
# scip 8.1.0: optimal solution; objective 1.008368421
# 164 simplex iterations
# 113 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.072702
# 89 simplex iterations
# scip 8.1.0: optimal solution; objective 1.001466048
# 7 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.068526
# 91 simplex iterations
# scip 8.1.0: optimal solution; objective 1.001171027
# 1022 simplex iterations
# 792 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.059846
# 90 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000977269
# 4 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.055693
# 91 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000809801
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.05365
# 91 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000927055
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.053491
# 94 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000918342
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.051048
# 96 simplex iterations
# scip 8.1.0: optimal solution; objective 1.001041194
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.048706
# 98 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000939173
# 4 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.043451
# 98 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000826953
# 1358 simplex iterations
# 877 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.029914
# 97 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000860576
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.026452
# 93 simplex iterations
# scip 8.1.0: optimal solution; objective 1.001334554
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.025174
# 93 simplex iterations
# scip 8.1.0: optimal solution; objective 1.001277032
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.015143
# 91 simplex iterations
# scip 8.1.0: optimal solution; objective 1.001115663
# 271 simplex iterations
# 182 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.01499
# 91 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000869141
# 761 simplex iterations
# 564 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1027.008906
# 91 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000826159
# 2001 simplex iterations
# 1519 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.997734
# 90 simplex iterations
# scip 8.1.0: optimal solution; objective 1.001154138
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.995252
# 94 simplex iterations
# scip 8.1.0: optimal solution; objective 1.001190881
# 4 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.972235
# 99 simplex iterations
# scip 8.1.0: optimal solution; objective 1.004296427
# 13 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.965665
# 99 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000981209
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.955598
# 99 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000981169
# 4 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.953405
# 105 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000837274
# 585 simplex iterations
# 429 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.951055
# 91 simplex iterations
# scip 8.1.0: optimal solution; objective 1.001016272
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.950661
# 91 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000458213
# 324 simplex iterations
# 311 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.942816
# 89 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000413535
# 1 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.936519
# 99 simplex iterations
# scip 8.1.0: optimal solution; objective 1.00046603
# 1 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.926318
# 102 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000455044
# 1 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.924448
# 97 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000420657
# 207 simplex iterations
# 193 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.912475
# 91 simplex iterations
# scip 8.1.0: optimal solution; objective 1.00114515
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.9116
# 91 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000859122
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.909509
# 91 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000591514
# 274 simplex iterations
# 251 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.906022
# 91 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000481079
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.903921
# 92 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000413355
# 30 simplex iterations
# 19 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.90143
# 95 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000443346
# 24 simplex iterations
# 25 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.897024
# 98 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000362991
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.895663
# 95 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000379493
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.89265
# 98 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000484707
# 1 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.892189
# 97 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000387504
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.891006
# 97 simplex iterations
# scip 8.1.0: optimal solution; objective 1.00040016
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.890473
# 97 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000337002
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.884415
# 102 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000997831
# 9 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.884244
# 101 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000744164
# 4 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.883634
# 100 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000292228
# 17 simplex iterations
# 9 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.882984
# 99 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000257834
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.882169
# 101 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000539028
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.881843
# 105 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000290599
# 669 simplex iterations
# 581 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.880906
# 106 simplex iterations
# scip 8.1.0: optimal solution; objective 1.00065931
# 3 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.880906
# 105 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000262353
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.879586
# 103 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000427648
# 1103 simplex iterations
# 847 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.878859
# 105 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000322861
# 222 simplex iterations
# 163 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.877117
# 107 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000367804
# 286 simplex iterations
# 229 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.876057
# 108 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000290976
# 580 simplex iterations
# 591 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.876054
# 107 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000220137
# 41 simplex iterations
# 25 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.87308
# 99 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000599509
# 1498 simplex iterations
# 1040 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.870334
# 101 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000529523
# 14 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.8662
# 101 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000392024
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.864731
# 104 simplex iterations
# scip 8.1.0: optimal solution; objective 1.00035892
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.862962
# 106 simplex iterations
# scip 8.1.0: optimal solution; objective 1.00032042
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.862511
# 106 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000333661
# 473 simplex iterations
# 440 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.860949
# 112 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000341161
# 191 simplex iterations
# 143 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.860912
# 112 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000177924
# 4 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.860814
# 111 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000284113
# 499 simplex iterations
# 365 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.860414
# 109 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000293492
# 670 simplex iterations
# 647 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.855959
# 105 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000323352
# 277 simplex iterations
# 251 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.855167
# 104 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000338756
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.852767
# 104 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000230974
# 326 simplex iterations
# 315 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.852321
# 105 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000215393
# 7 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.851725
# 103 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000115754
# 10 simplex iterations
# 3 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.851673
# 103 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000156573
# 288 simplex iterations
# 193 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.851407
# 106 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000134864
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.850663
# 103 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000133602
# 119 simplex iterations
# 87 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.850622
# 104 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000135711
# 100 simplex iterations
# 77 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.849831
# 100 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000262564
# 690 simplex iterations
# 575 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.846609
# 101 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000184463
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.843967
# 100 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000210141
# 489 simplex iterations
# 377 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.842015
# 100 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000280832
# 376 simplex iterations
# 353 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.841927
# 100 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000187571
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.841706
# 99 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000114152
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.841214
# 97 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000177057
# 201 simplex iterations
# 159 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.841023
# 99 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000182493
# 4 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.838608
# 98 simplex iterations
# scip 8.1.0: optimal solution; objective 1.00017785
# 113 simplex iterations
# 101 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.837637
# 99 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000130859
# 2 simplex iterations
# 1 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.83736
# 96 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000089336
# 144 simplex iterations
# 105 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.837227
# 98 simplex iterations
# scip 8.1.0: optimal solution; objective 1.000099934
# 69 simplex iterations
# 67 branch-and-cut nodes
# scip 8.1.0: optimal solution; objective 1026.837
# 100 simplex iterations
# scip 8.1.0: optimal solution; objective 1

# %% [markdown]
# ### Compute and display integer solution

# %%
# Compute integer solution
Master.option['relax_integrality'] = 0
# Master.solve()

# %% [markdown]
# ### Import model in scip

# %%
# Create scip reader and read in the NL file exported in the previous step
grb_model = Master.exportscipModel()

class MyCallback(gpy.GRBCallback):
    def run(self, where):
        try:
            if where == gpy.GRB_CB_MIP:
                runtime = self.getDouble(gpy.GRB_CB_RUNTIME)                
                if runtime >= self._stoprule['time'][self._current]:
                    print('Reducing gap tolerance to %f at %d seconds' % 
                    (self._stoprule['gaptol'][self._current], self._stoprule['time'][self._current]))
                    grb_model.setDoubleParam('MIPGap', self._stoprule['gaptol'][self._current])
                    self._current += 1                
        except Exception as e:
            print('Error:', e)
        return 0
            

# Create callback object and attach properties
cb = MyCallback()

if len(stopdata) == 0:
    cb._stoprule = {'time': (1e+10,), 'gaptol': (1,)}
else:
    exec(open(stopdata+'.py').read(), globals())
    stopdict['time'] += (1e+10,)
    stopdict['gaptol'] += (1,)
    cb._stoprule = stopdict
cb._current = 0

# Solve with scip API, using the callback defined above
grb_model.setIntParam('LogToConsole', 1)
grb_model.setCallback(cb)
grb_model.optimize()

# Export model from scip and import in the running AMPL instance
Master.importscipSolution(grb_model)
# Out:
# Reducing gap tolerance to 0.000200 at 15 seconds
# scip 8.1.0: optimal solution; objective 1027
# 587587 simplex iterations
# No dual variables returned.

# %% [markdown]
# ### Retrieve solution

# %%
# Prepare summary data
summary = {
    'Data': cutdata,
    'Obj': int(Master.obj['TotalRawRolls'].value()),
    'Waste': Master.getValue(
             'sum {p in PATTERNS} Cut[p] * \
                (rawWidth - sum {w in WIDTHS} w*rolls[w,p])'
             )
}

# Retrieve patterns and solution
npatterns = int(Master.param['nPatterns'].value())
rolls = Master.param['rolls'].getValues().toDict()
cutvec = Master.var['Cut'].getValues().toDict()

print("%d patterns generated" % (npatterns))

# Prepare solution data
solution = [
    ([int(rolls[widths[i], p+1]) 
      for i in range(len(widths))], int(cutvec[p+1]))
    for p in range(npatterns)
    if cutvec[p+1] > 0
][:50]

print("%d patterns used" % (len(solution)))
# Out:
# 253 patterns generated
# 50 patterns used

# %% [markdown]
# ### Display solution

# %%
# Create plot of solution
cuttingPlot(roll_width, widths, summary, solution)

# %%
Master.solve()
Master.option['scip_options'] = 'outlev=1 bestbound=1'
# Out:
# scip 8.1.0: optimal solution; objective 1027
# 88 simplex iterations

# %%
Master.getValue('TotalRawRolls')
# Out:
# 1027.0
